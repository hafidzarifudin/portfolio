# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Input Dataset

# %%
df = pd.read_csv('e-shop clothing 2008.csv', delimiter=';')
df
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 2       2008      4    1      3       29           1                       2
# 3       2008      4    1      4       29           1                       2
# 4       2008      4    1      5       29           1                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165471  2008      8   13      1       34       24026                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
df.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        2     1
# 1        2     1
# 2        1     1
# 3        2     1
# 4        1     1

# %%
df.describe()
# Out:
#            year          month            day          order        country  \
# count  165474.0  165474.000000  165474.000000  165474.000000  165474.000000
# mean     2008.0       5.585887      14.524554       9.817476      26.952621
# std         0.0       1.328160       8.830374      13.478411       7.150691
# min      2008.0       4.000000       1.000000       1.000000       1.000000
# 25%      2008.0       4.000000       7.000000       2.000000      29.000000
# 50%      2008.0       5.000000      14.000000       6.000000      29.000000
# 75%      2008.0       7.000000      22.000000      12.000000      29.000000
# max      2008.0       8.000000      31.000000     195.000000      47.000000
#
#           session ID  page 1 (main category)         colour       location  \
# count  165474.000000           165474.000000  165474.000000  165474.000000
# mean    12058.417056                2.400842       6.227655       3.258198
# ...

# %% [markdown]
# # Analisis Dataset

# %%
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(111)

data_boxplot = [df['country'], df['colour'], df['price']]

boxplot = ax.boxplot(data_boxplot, patch_artist=True, notch='True', vert=0)
 
colours = ['#ebeb1e', '#1eeb4e', '#1e32eb']
 
for patch, colour in zip(boxplot['boxes'], colours):
    patch.set_facecolor(colour)
    
# mengubah warna pada garis median
for median in boxplot['medians']:
    median.set(color='black', linewidth=2)
     
# Label pada x-axis
ax.set_yticklabels(['country', 'colour', 'price'])
 
# judul
plt.title("Boxplot Analysis")
plt.grid()
plt.show(boxplot)

# %%
fig = plt.figure(figsize=(16, 2))
ax = fig.add_subplot(111)

boxplot = ax.boxplot(df['order'], patch_artist=True, notch='True', vert=0)
 
colours = ['#e72929']
 
for patch, colour in zip(boxplot['boxes'], colours):
    patch.set_facecolor(colour)
    
# mengubah warna pada garis median
for median in boxplot['medians']:
    median.set(color='black', linewidth=2)

# label pada x-axis
ax.set_yticklabels(['order'])
 
# judul
plt.title("Boxplot Analysis")
plt.show(boxplot)

# %%
fig = plt.figure(figsize=(7, 15))
plt.scatter(df['month'], df['country'])

xticks_num = [4, 5, 6, 7, 8]
xticks_str = ['April', 'May', 'June', 'July', 'August']
yticks = np.arange(1,48).tolist()

plt.grid()
plt.xticks(xticks_num, xticks_str)
plt.yticks(yticks)
plt.title('Month to Country Plot')
plt.xlabel('\nMonth')
plt.ylabel('Country Code')
plt.show()

# %%
order = df['order']
order_x = ['<= 40', '41 - 80', '81 - 120', '121 - 160', '> 160']
order_y = [sum(order<=40), 
           sum((order>40) & (order<=80)), 
           sum((order>80) & (order<=120)), 
           sum((order>120) & (order<=160)), 
           sum(order>160)]

# %%
def labels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]+2000, y[i], ha = 'center')
plt.figure(figsize=(10,10))
plt.bar(order_x, order_y)
labels(order_x, order_y)
plt.title('Order Count Plot')
plt.xlabel('Order Quantity')
plt.ylabel('Amount of Transactions')
plt.show()

# %%
def labels(x,y):
    for i in range(len(x)):
        plt.text(i+4, y[i]+5000, y[i], ha = 'center')

fig = plt.figure(figsize=(7, 5))

month = df['month'].value_counts().sort_index().keys().tolist()
order_per_month = df.groupby('month')['order'].sum()

xticks_str = ['April', 'May', 'June', 'July', 'August']

plt.bar(month, order_per_month)
labels(month, order_per_month.tolist())
plt.xticks(month, xticks_str)
plt.title('Order per Month Plot')
plt.xlabel('\nMonth')
plt.ylabel('Order')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
plt.scatter(np.arange(df['order'].count()), df['order'])
plt.grid(axis='y')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
april = df['order'][df['month']==4].count()
plt.scatter(np.arange(april), df['order'][df['month']==4])
plt.title('Total Order April')
plt.show()

# %%
def labels(x,y):
    for i in range(len(x)):
        plt.text(i+1, y[i]+15000, y[i], ha = 'center')

fig = plt.figure(figsize=(16, 10))

country = df['country'].value_counts().sort_index().keys().tolist()
order_per_country = df.groupby('country')['order'].sum()

plt.scatter(country, order_per_country)
plt.plot(country, order_per_country)
labels(country, order_per_country.tolist())
plt.xticks(country)
plt.title('Order per Country')
plt.xlabel('\nCountry Code')
plt.ylabel('Amount of Order')
plt.show()

# %%
order_day_one = df['order'][df['month']==4][df['day']==1]

fig = plt.figure(figsize=(16,10))
plt.scatter(np.arange(order_day_one.count()), order_day_one)
plt.show()

# %%
order_day_x = []
for i in df['month'].value_counts().sort_index().keys().tolist():
    for j in df['day'].value_counts().sort_index().keys().tolist():
        order_day_x.append(df['order'][df['month']==i][df['day']==j].sum())
order_day_x
# Out:
# [25202,
#  31119,
#  16446,
#  17031,
#  13379,
#  12521,
#  17313,
#  22377,
#  10504,
#  18726,
#  12854,
#  11364,
#  7207,
#  19912,
#  11772,
#  18078,
#  13827,
#  20303,
#  21140,
#  11253,
#  18826,
#  12348,
#  16505,
#  8539,
#  8044,
#  10152,
#  7889,
#  11860,
#  24115,
#  9106,
#  0,
#  17499,
#  7905,
#  4164,
#  12771,
#  13543,
#  8945,
#  11086,
#  25155,
#  9495,
#  7738,
#  11037,
#  20034,
#  6725,
#  12471,
#  14240,
#  15774,
#  6999,
#  8274,
#  12563,
#  11268,
#  11451,
#  8050,
#  10608,
#  8944,
#  16946,
#  6877,
#  11990,
#  11721,
#  16662,
#  4353,
#  5632,
#  6945,
#  6786,
#  12792,
#  11434,
#  12502,
#  8942,
#  9827,
#  6465,
#  11616,
#  26716,
#  10052,
#  17661,
#  14042,
#  3994,
#  5540,
#  7705,
#  10560,
#  10916,
#  9735,
#  7039,
#  7091,
#  12484,
#  7236,
#  10283,
#  7970,
#  13087,
#  12024,
#  6305,
#  7532,
#  8281,
#  0,
#  6005,
#  12896,
#  12918,
#  8016,
#  6294,
#  12340,
#  8041,
#  13656,
#  9548,
#  9305,
#  10606,
# ...

# %%
fig = plt.figure(figsize=(16,10))

plt.scatter(np.arange(len(order_day_x)), order_day_x)
plt.xticks(np.arange(0,len(order_day_x),5))
plt.yticks(np.arange(0,34000,1000))
plt.grid()
plt.title('Order per Day')
plt.xlabel('\nDay')
plt.ylabel('Amount of Order')
plt.show()

# %% [markdown]
# urutan bagian katalog yang sering diklik untuk dipesan:
# pojok kiri atas,
# tengah atas,
# tengah bawah,
# pojok kiri bawah,
# pojok kanan atas,
# pojok kanan bawah.

# %%
df['location'].value_counts()
# Out:
# 1    34532
# 2    33383
# 5    27783
# 4    27377
# 3    21656
# 6    20743
# Name: location, dtype: int64
